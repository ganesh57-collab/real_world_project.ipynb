# %% [markdown]
# ### Data Upload
#
# To run the analysis, please upload the `sales_data.csv` file to your Colab environment. You can do this by clicking the 'Files' icon on the left sidebar (folder icon), then clicking the 'Upload' icon (page with an arrow pointing up) and selecting `sales_data.csv` from your local machine. If you don't have the file, a dummy file will be created below.

# %%
# Create a dummy sales_data.csv for demonstration if it doesn't exist
import os

file_path = "sales_data.csv"
if not os.path.exists(file_path):
    dummy_data = {
        'Product': ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C', 'A'],
        'Month': [1, 1, 1, 2, 2, 2, 3, 3, 3, 4],
        'Sales': [100, 150, 200, 120, 180, 220, 110, 160, 210, 130]
    }
    dummy_df = pd.DataFrame(dummy_data)
    dummy_df.to_csv(file_path, index=False)
    print(f"Dummy '{file_path}' created for demonstration.")
else:
    print(f"'{file_path}' already exists. Skipping dummy file creation.")
# Out:
# Dummy 'sales_data.csv' created for demonstration.

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("sales_data.csv")

print("First 5 Rows")
print(data.head())

print("\nDataset Info")
print(data.info())

print("\nMissing Values")
print(data.isnull().sum())

print("\nStatistical Summary")
print(data.describe())

total_sales = data["Sales"].sum()

print("\nTotal Sales:", total_sales)

top_products = data.groupby("Product")["Sales"].sum()

print("\nTop Products")
print(top_products)

top_products.plot(kind="bar")

plt.xlabel("Products")
plt.ylabel("Sales")
plt.title("Product Sales Analysis")
plt.show()

monthly_sales = data.groupby("Month")["Sales"].sum()

monthly_sales.plot(kind="line")

plt.xlabel("Month")
plt.ylabel("Sales")
plt.title("Monthly Sales Trend")
plt.show()

print("\nProject Completed")
# Out:
# First 5 Rows
#   Product  Month  Sales
# 0       A      1    100
# 1       B      1    150
# 2       C      1    200
# 3       A      2    120
# 4       B      2    180
#
# Dataset Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Product  10 non-null     object
#  1   Month    10 non-null     int64
#  2   Sales    10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes
# None
#
# Missing Values
# Product    0
# Month      0
# Sales      0
# dtype: int64
#
# Statistical Summary
#            Month       Sales
# count  10.000000   10.000000
# mean    2.200000  158.000000
# std     1.032796   43.153473
# min     1.000000  100.000000
# 25%     1.250000  122.500000
# 50%     2.000000  155.000000
# 75%     3.000000  195.000000
# max     4.000000  220.000000
#
# Total Sales: 1580
#
# Top Products
# Product
# A    460
# ...
